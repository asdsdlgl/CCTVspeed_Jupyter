# %% [markdown]
# #Import Package<br>
# 備註: 此程式會將frame數分為兩個model去訓練，並分別向左右延伸，找到最佳的訓練與測試集

# %%
# -*- coding: utf-8 -*-
import os

import pandas as pd

from datetime import datetime
from datetime import timedelta
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot as plt
from keras.utils import Sequence, plot_model
from keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings("ignore")
#from models import *    #在jupyter中 改為 下面cell的 %run models.ipnyb
import tensorflow as tf
import random as rn
rn.seed(666)
tf.set_random_seed(666)


config = tf.ConfigProto()           # 此三行的目的是讓TensorFlow在運行過程中動態申請顯存，需要多少就申請多少
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Import model<br>
# 包括 c3d、c3g25、c4g12、c5g6、c6g3、lrcn

# %%
# %run models.ipynb

# %% [markdown]
# #Class Define<br>
# 論文第10頁<br>
# 參考 : 英文 https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly <br>
#       中文 https://blog.csdn.net/m0_37477175/article/details/79716312

# %%
class DataGenerator(Sequence): 
    'Generates data for Keras'
    def __init__(self, list_IDs_1, list_IDs_3, labels, fnum, peak, shuffle=True):
        'Initialization'
        self.batch_size = batch_size
        self.labels = labels
        self.list_IDs_1 = list_IDs_1
        self.list_IDs_3 = list_IDs_3
        self.fnum = fnum
        self.shuffle = shuffle
        self.on_epoch_end()
        self.peak = peak

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs_1) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        # Find list of IDs
        list_IDs_temp_1, y = [self.list_IDs_1[k] for k in indexes],\
                             [self.labels[k] for k in indexes]
        # Generate data
        X1 = self.__data_generation(list_IDs_temp_1, indexes)
        return X1, np.array(y, dtype=int)

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs_1))
        if self.shuffle == True:
            np.random.seed(666)
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp_1, y_index):
        'Generates data containing batch_size samples'
        # Initialization
        X1 = []
        # Generate data
        for ID, y_ID in zip(list_IDs_temp_1, y_index):
            # Store sample
            x_1 = list(np.load(ID + '.npy'))
            if len(x_1) >= 120:                       # 影片frame數 > 120 ，取70-119 frame
                x_1 = x_1[70:120]
            else:                                     # <120 則取 1-50 frame
                x_1 = x_1[:frame_num]
            while len(x_1) < self.fnum:               # <50  改成全部為0的陣列
                x_1.append(np.zeros_like(x_1[0]))
            X1.append(x_1)
        X1 = np.array(X1)                            # 因為batch設定32的關係  每次output為一(32,50,x,y,1)
        return X1
    
class FrameInterval:
    def __init__(self):
        self.train_df = pd.DataFrame(columns=['data'], dtype=str)
        self.test_df = pd.DataFrame(columns=['data'], dtype=str)
        self.val_df = pd.DataFrame(columns=['data'], dtype=str)

    def add_train(self, data, datatime):
        self.train_df.loc[datatime] = [data]
        self.train_df.index = pd.to_datetime(self.train_df.index)

    def add_test(self, data, datatime):
        self.test_df.loc[datatime] = [data]
        self.test_df.index = pd.to_datetime(self.test_df.index)

    def add_val(self, data, datatime):
        self.val_df.loc[datatime] = [data]
        self.val_df.index = pd.to_datetime(self.val_df.index)

# %% [markdown]
# #Define compare_mae<br>
# 比較MAE(平均絕對誤差) |y-^y|/m <br>
# 第一輪跑state = 0 所以先fit_generator 當等於state = 1時就predict_generator

# %%
def compare_mae(new, train, test, frame_num, mae, model, stage, dir):
    global state
    print("Stage %d" % stage, file=open(total_name, 'a'))
    print("Current MAE:", "%.3f" % mae, file=open(total_name, 'a'))
    new_train = sorted(new + train)
    new_test = sorted(new + test)
    X_train = []
    y_train_index = []
    X_test = []
    y_test_index = []
    X_val = []
    y_val_index = []
    for t in new_test:
        X_test += FrameList[t].test_df['data'].tolist() #Series to List
        y_test_index += FrameList[t].test_df.index      #list of Timestamp
        X_val += FrameList[t].val_df['data'].tolist()
        y_val_index += FrameList[t].val_df.index
    for t in new_train:
        X_train += FrameList[t].train_df['data'].tolist()
        y_train_index += FrameList[t].train_df.index
    X_train_fnum = frame_df.loc[y_train_index]    #dataframe , select data of the days
    X_test_fnum = frame_df.loc[y_test_index]
    X_val_fnum = frame_df.loc[y_val_index]
    y_train = vd_df.loc[y_train_index, feature].values
    y_test = vd_df.loc[y_test_index, feature].values
    y_val = vd_df.loc[y_val_index, feature].values
    print("New Train Length:", len(X_train), file=open(total_name, 'a'))
    print("New Test Length:", len(X_test), file=open(total_name, 'a'))
    print("New Val Length:", len(X_val), file=open(total_name, 'a'))

    X_train = np.array(X_train)
    X_train_fnum = np.array(X_train_fnum)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    X_test_fnum = np.array(X_test_fnum)
    y_test = np.array(y_test)
    X_val = np.array(X_val)
    X_val_fnum = np.array(X_val_fnum)
    y_val = np.array(y_val)
    testing_generator = DataGenerator(X_test, X_test_fnum, y_test, frame_num, dir, False) #將資料分批 IO較快

    mae_2, mae_3 = 100, 100
    if stage:     #後 執行
        testPrdct = model.predict_generator(generator=testing_generator, max_queue_size=500, workers=32, verbose=1)
        testPrdct = np.squeeze(testPrdct)
        mae_2 = abs(y_test[:len(testPrdct)] - testPrdct).mean()
        print("Merge Test MAE:", "%.3f" % mae_2, file=open(total_name, 'a'))

        plt.figure(num=None, figsize=(50, 5))
        plt.tick_params(labelsize=30)
        plt.plot(y_test, lw=2, label='Target')
        plt.plot(testPrdct, lw=2, label='Predict')
        plt.legend(loc=1, prop={'size': 20})
        plt.tight_layout()
        plt.grid()
        # plt.title(mae_2)
        plt.savefig(
            "plot/" + cctv_Id + "/" + dir + "/stage_%d_merge1.png" % stage)
        plt.close('all')
        plt.clf()
        plt.cla()
    if state == 0:  #先被執行 python中允許fit跟predict在不同次的function call
        training_generator = DataGenerator(X_train, X_train_fnum, y_train, frame_num, dir, True)
        validation_generator = DataGenerator(X_val, X_val_fnum, y_val, frame_num, dir, True)
        model_temp = model
        history = model_temp.fit_generator(generator=training_generator, validation_data=validation_generator,
                                           epochs=epochs, steps_per_epoch=len(X_train) // batch_size,
                                           validation_steps=len(X_val) // batch_size,
                                           max_queue_size=500, verbose=1, callbacks=[early_stopping], workers=32)
        plt.plot(history.history['loss'], label='train')
        plt.plot(history.history['val_loss'], label='validation')
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(loc=1)
        plt.tight_layout()
        plt.grid()
        plt.savefig(
            "plot/" + cctv_Id + "/" + dir + "/loss.png")
        testPrdct_2 = model_temp.predict_generator(generator=testing_generator, max_queue_size=500, workers=32, verbose=1)
        testPrdct_2 = np.squeeze(testPrdct_2)
        mae_3 = abs(y_test[:len(testPrdct_2)] - testPrdct_2).mean()
        print("Merge All MAE:", "%.3f" % mae_3, file=open(total_name, 'a'))
        plt.figure(num=None, figsize=(50, 5))
        plt.tick_params(labelsize=30)
        plt.plot(y_test, lw=2, label='Target')
        plt.plot(testPrdct_2, lw=2, label='Predict')
        plt.tight_layout()
        plt.grid()
        # plt.title("MAE: %.3f" % mae_3)
        plt.legend(loc=1, prop={'size': 20})
        plt.savefig(
            "plot/" + cctv_Id + "/" + dir + "/stage_%d_merge2.png" % stage)
        plt.close('all')
        plt.clf()
        plt.cla()
    MAE = np.array([mae, mae_2, mae_3])
    mini = MAE.argmin()
    if stage == 0:
        state = 0
        print("State: Initial", file=open(total_name, 'a'))
        return new_train, new_test, mae_3, model_temp, False, testPrdct_2
    if mini == 0:           #mini = 0 代表原本的是最準確的 所以就停止merging
        state = 0
        print("State: Stop merging", file=open(total_name, 'a'))
        return train, test, mae, model, True, None
    elif mini == 1:
        state = 1
        print("State: Add test -> %d" % new[0], file=open(total_name, 'a'))
        return train, new_test, mae_2, model, False, testPrdct
    else:
        state = 0
        print("State: Add train & test -> %d" % new[0], file=open(total_name, 'a'))
        return new_train, new_test, mae_3, model_temp, False, testPrdct_2

# %% [markdown]
# #Basic setting<br>
# day1, train_dayLast: 訓練時間<br>
# test_day1, dayLast: 測試時間<br>
# val_day1, val_dayLast: 驗證時間<br>
# feature: 選擇真值(Spd_Max, Spd_Min, Spd_Avg)

# %%
vds = ['nfbVD-N5-N-16.900-M-PS', 'nfbVD-N5-N-18.313-M-PS', 'nfbVD-N5-N-22.510-M-PS', 'nfbVD-N5-N-25.310-M-PS',
       'nfbVD-N5-S-18.312-M-PS', 'nfbVD-N5-S-19.677-M-PS', 'nfbVD-N5-S-21.063-M-PS', 'nfbVD-N5-S-23.910-M-PS']

cctvs = ['nfbCCTV-N5-N-16.915-M', 'nfbCCTV-N5-N-18.308-M', 'nfbCCTV-N5-N-22.514-M', 'nfbCCTV-N5-N-25.309-M',
         'nfbCCTV-N5-S-18.339-M', 'nfbCCTV-N5-S-19.7-M', 'nfbCCTV-N5-S-21.048-M', 'nfbCCTV-N5-S-23.896-M']
vds = ["nfbVD-N5-S-21.063-M-PS", "nfbVD-N5-S-23.910-M-PS", "nfbVD-N5-N-25.310-M-PS"]
cctvs = ['nfbCCTV-N5-S-21.048-M', 'nfbCCTV-N5-S-23.896-M', 'nfbCCTV-N5-N-25.309-M']

features = ['Spd_Max', 'Spd_Avg', 'Spd_Min']

day1 = datetime.strptime('20190728 0600', "%Y%m%d %H%M")
day1_str = day1.strftime("%Y%m%d %H%M")
train_dayLast = datetime.strptime('20190729 2359', "%Y%m%d %H%M")

test_day1 = datetime.strptime('20190728 0600', "%Y%m%d %H%M")
test_day1_str = test_day1.strftime("%Y%m%d %H%M")
dayLast = datetime.strptime('20190729 2359', "%Y%m%d %H%M")
dayLast_str = dayLast.strftime("%Y%m%d %H%M")

val_day1 = datetime.strptime('20190729 0600', "%Y%m%d %H%M")
val_dayLast = val_day1 + timedelta(days=6) - timedelta(minutes=1)

# day1 = datetime.strptime('20190320 0600', "%Y%m%d %H%M")
# day1_str = day1.strftime("%Y%m%d %H%M")
# train_dayLast = datetime.strptime('20190320 0630', "%Y%m%d %H%M")
#
# test_day1 = datetime.strptime('20190328 0600', "%Y%m%d %H%M")
# test_day1_str = test_day1.strftime("%Y%m%d %H%M")
# dayLast = datetime.strptime('20190328 0630', "%Y%m%d %H%M")
# dayLast_str = dayLast.strftime("%Y%m%d %H%M")
# Add VDs
# dt_dtypes = {'Spd0': int, 'Spd1': int, 'Spd2': int, 'SpdMax': int, 'SpdMin': int, 'SpdAvg': int}
# train_dt_index = pd.date_range(day1, periods=(train_dayLast - day1).total_seconds() // 60 + 1, freq='T')
# test_dt_index = pd.date_range(test_dayFirst, periods=(dayLast - test_dayFirst).total_seconds() // 60 + 1, freq='T')

# %% [markdown]
# #Todo<br>
# model: 要訓練的神經網路模型<br>
# filename: 選擇vd真值的csv檔<br>
# 備註: 此程式會將frame數分為兩個model去訓練，並分別向左右延伸，找到最佳的訓練與測試集<br>
# frame_num : 取50frame 論文第10頁

# %%
# Todo: Tune the fitting parameters
feature = 'Spd_Max'
batch_size = 32
epochs = 100
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='auto',
                               verbose=0, restore_best_weights=True)
"""Choose model"""
name, model = c3g25()

total_name = 'plot/All_log.txt'
open(total_name, 'w').close()

for cctv_Id, vd_Id in zip(cctvs, vds):
    print(cctv_Id)
    print(name)
    print(cctv_Id, file=open(total_name, 'a'))
    vdDir = 'D:/vd/' + vd_Id + '/vd_speed/'
    cctvDir = 'D:/wcs/cctv/' + cctv_Id + "/"
    filename = vdDir + 'vdspd_20190728_20190729.csv'   #'vdspd_20190322_20190608.csv'
    total_frames = cctvDir + "frame_num.txt"
    vd_df = pd.read_csv("D:/vd/nfbVD-N5-N-25.310-M-PS/vd_speed/vdspd_20190728_20190729.csv", infer_datetime_format=True, index_col=0)
    vd_df.index = pd.to_datetime(vd_df.index)
    vd_df = vd_df.shift(-1)                            #往上位移一位 因為資料取得有延遲
    vd_df.loc[vd_df.index[len(vd_df)-1]] = 90          #將位移完後的nan填補90
    frame_df = pd.read_csv(total_frames, infer_datetime_format=True, index_col=0, header=None)
    frame_df.index = pd.to_datetime(frame_df.index)   #必須要用to_datetime 因為loc才能找到 從2019/07/29 ---> 2019-07-29
    print(frame_df.index)
    total_test_index = []
    FrameList = []
    with open(cctvDir + "frame_interval.txt") as f:
        content = f.readlines()
    frame_interval = np.array([x.strip() for x in content], dtype=int)
    for i in range(len(content)):
        FrameList.append(FrameInterval())
    print(datetime.now())

    if not os.path.exists("plot/" + cctv_Id + "/peak_1"):
        os.makedirs("plot/" + cctv_Id + "/peak_1")
        os.makedirs("plot/" + cctv_Id + "/peak_2")
    else:
        for f in os.listdir("plot/" + cctv_Id + "/peak_1"):
            os.remove("plot/" + cctv_Id + "/peak_1/" + f)
        for f in os.listdir("plot/" + cctv_Id + "/peak_2"):
            os.remove("plot/" + cctv_Id + "/peak_2/" + f)
    train_count = 0
    test_count = 0
    val_count = 0
    day = day1                       #first day of training day
    while day <= train_dayLast:
        # print(day)
        if not os.path.exists(cctvDir + day.strftime("%Y%m%d") + "_" + day.strftime("%H%M") + ".npy")\
                or day not in vd_df.index:
            day += timedelta(minutes=1)
            continue
        train_count += 1
        FrameList[int(frame_df.loc[day]) // 10]\
            .add_train(cctvDir + day.strftime("%Y%m%d") + "_" + day.strftime("%H%M"), day)
          #     "D:/wcs/cctv/nfbCCTV-N5-S-21.048-M/20190729_1644"      ,      "2019-07-29 16:44:00"
        day += timedelta(minutes=1)

    day = test_day1                 #first day of testing day
    while day <= dayLast:
        # print(day)
        if not os.path.exists(cctvDir + day.strftime("%Y%m%d") + "_" + day.strftime("%H%M") + ".npy") \
                or day not in vd_df.index:
            day += timedelta(minutes=1)
            continue
        test_count += 1
        FrameList[int(frame_df.loc[day]) // 10] \
            .add_test(cctvDir + day.strftime("%Y%m%d") + "_" + day.strftime("%H%M"), day)
        total_test_index.append(day)
        day += timedelta(minutes=1)

    day = val_day1
    while day <= val_dayLast:       #first day of validating day
        # print(day)
        if not os.path.exists(cctvDir + day.strftime("%Y%m%d") + "_" + day.strftime("%H%M") + ".npy") \
                or day not in vd_df.index:
            day += timedelta(minutes=1)
            continue
        val_count += 1
        FrameList[int(frame_df.loc[day]) // 10] \
            .add_val(cctvDir + day.strftime("%Y%m%d") + "_" + day.strftime("%H%M"), day)
        day += timedelta(minutes=1)

    print("Total Train:", train_count, file=open(total_name, 'a'))
    print("Total test:", test_count, file=open(total_name, 'a'))
    print("Total val:", val_count, file=open(total_name, 'a'))
    print("Frame Num:", len(frame_df))                                        # 取shape的(x,y,channel)不包含數量 shape[0]是數量
    shape = np.load(FrameList[5].train_df.iloc[0].values[0]+'.npy').shape[1:] #學長好像沒用到? shape(59,72,106,1)
    
    #shape2 = np.load(FrameList[5].train_df.iloc[0].values[0]+'_timestamp.npy').shape[1:]
    # my_models = [build_model(shape), build_model_2(shape), build_model_3(shape)]

    ModelTrain_1 = [list(frame_interval).index(sorted(frame_interval)[-1])] #找出frame數最大的index
    ModelTrain_1 = [ModelTrain_1[0] - 1] + ModelTrain_1 #向左找 備註 : 就是frame.png的最高峰(詳細看論文)
    ModelTest_1 = ModelTrain_1.copy()

    if abs(list(frame_interval).index(sorted(frame_interval)[-2]) -
           list(frame_interval).index(sorted(frame_interval)[-1])) < 5:
        ModelTrain_2 = [list(frame_interval).index(sorted(frame_interval)[-3])] #如果最高峰跟第二高峰相差5個index內
    else:                                                                       #就選擇第三高峰 否則選擇第二高峰的index
        ModelTrain_2 = [list(frame_interval).index(sorted(frame_interval)[-2])]
    ModelTrain_2 = [ModelTrain_2[0] - 1] + ModelTrain_2                        #同時向左找一個index
    ModelTest_2 = ModelTrain_2.copy()

    train = [ModelTrain_1, ModelTrain_2]    #[ [最高峰index 最高峰index-1(向左找)],[最二峰index 最二峰index-1(向左找)] ]
    test = [ModelTest_1, ModelTest_2]

    total_test = []

    for peaks in range(2):
        state = 0
        Index = train[peaks][0] - 1
        frame_num = train[peaks][-1]*10 if train[peaks][-1]*10 < 90 else 90
        frame_num = 50
        my_model = model
        print("\n*Peak %d" % (peaks+1), file=open(total_name, 'a'))
        train[peaks], test[peaks], currentMAE, my_model, isStopMerging, predict =\
            compare_mae([], train[peaks], test[peaks], frame_num, 100, my_model, 0, "peak_%d" % (peaks+1))
        # file_name = "plot/" + cctv_Id + "/" + test_day1_str + '_' + dayLast_str + '/log.txt'
        # open(file_name, 'w').close()
        stages = 0
        print("Frame Num:", frame_num, file=open(total_name, 'a'))
        print("Left Hand Side", file=open(total_name, 'a'))
        while Index >= 0 and not isStopMerging:                      #index 從最高峰往左找
            stages += 1
            print(Index)
            print("Index:", Index, file=open(total_name, 'a'))
            if len(FrameList[Index].train_df) > 60 and len(FrameList[Index].val_df) > 0 \
                    and len(FrameList[Index].test_df) > 0:
                train[peaks], test[peaks], currentMAE, my_model, isStopMerging, p = \
                    compare_mae([Index], train[peaks], test[peaks], frame_num, currentMAE, my_model, stages, "peak_%d" % (peaks+1))
                if p is not None:
                    predict = p
            else:
                if len(FrameList[Index].test_df) > 0 and len(FrameList[Index].val_df) > 0:
                    state = 1
                    train[peaks], test[peaks], currentMAE, my_model, isStopMerging, p = \
                        compare_mae([Index], train[peaks], test[peaks], frame_num, currentMAE, my_model, stages,
                                    "peak_%d" % (peaks + 1))
                    if p is not None:
                        predict = p
                else:
                    print("No data!", file=open(total_name, 'a'))
                    print("Train List:", train[peaks], file=open(total_name, 'a'))
                    print("Test List:", test[peaks], file=open(total_name, 'a'))
                    print("", file=open(total_name, 'a'))
                    break
            print("Train List:", train[peaks], file=open(total_name, 'a'))
            print("Test List:", test[peaks], file=open(total_name, 'a'))
            print("", file=open(total_name, 'a'))
            Index -= 1
        state = 0
        isStopMerging = False
        print("Right Hand Side", file=open(total_name, 'a'))
        Index = train[peaks][-1] + 1                               #index 從最高峰往右找
        while Index < 21 and not isStopMerging:
            stages += 1
            print(Index)
            print("Index:", Index, file=open(total_name, 'a'))
            if len(FrameList[Index].train_df) > 60 and len(FrameList[Index].val_df) > 0 \
                    and len(FrameList[Index].test_df) > 0:
                train[peaks], test[peaks], currentMAE, my_model, isStopMerging, p = \
                    compare_mae([Index], train[peaks], test[peaks], frame_num, currentMAE, my_model, stages, "peak_%d" % (peaks+1))
                if p is not None:
                    predict = p
            else:
                if len(FrameList[Index].test_df) > 0 and len(FrameList[Index].val_df) > 0:
                    state = 1
                    train[peaks], test[peaks], currentMAE, my_model, isStopMerging, p = \
                        compare_mae([Index], train[peaks], test[peaks], frame_num, currentMAE, my_model, stages,
                                    "peak_%d" % (peaks + 1))
                    if p is not None:
                        predict = p
                else:
                    print("No data!", file=open(total_name, 'a'))
                    print("Train List:", train[peaks], file=open(total_name, 'a'))
                    print("Test List:", test[peaks], file=open(total_name, 'a'))
                    print("", file=open(total_name, 'a'))
                    break
            print("Train List:", train[peaks], file=open(total_name, 'a'))
            print("Test List:", test[peaks], file=open(total_name, 'a'))
            print("", file=open(total_name, 'a'))
            Index += 1
        total_test += test[peaks]
        index = 0
        for t in test[peaks]:
            if len(FrameList[t].test_df) == 0:
                continue
            temp = predict[index:index+len(FrameList[t].test_df)].tolist()
            while len(temp) < len(FrameList[t].test_df):
                temp.append(temp[-1])
            index += len(FrameList[t].test_df)
            FrameList[t].test_df.insert(loc=0, column='predict', value=temp)
        print("------------------", file=open(total_name, 'a'))
        my_model.save("plot/" + cctv_Id + "/peak_%d" % (peaks+1) + "/model.h5")
    predict_df = pd.DataFrame(columns=['value'])
    for i in total_test_index:
        for j in total_test:
            if i in FrameList[j].test_df.index:
                predict_df.loc[i] = [FrameList[j].test_df.loc[i]['predict']]
    df = pd.DataFrame(index=total_test_index)
    predict_all = np.array(predict_df.loc[total_test_index, 'value'].values)
    vd_all = np.array(vd_df.loc[total_test_index, feature].values)
    df.insert(loc=0, column='target', value=vd_all)
    df.insert(loc=0, column='predict', value=predict_df)
    df = df.replace(r'\s+', np.nan, regex=True).fillna(method='ffill')
    df = df.replace(r'\s+', np.nan, regex=True).fillna(method='bfill')
    df.to_csv("plot/" + cctv_Id + "/total_result.csv")
    print("Total predict:", len(predict_df), file=open(total_name, 'a'))
    print("Total test:", len(vd_all), file=open(total_name, 'a'))
    y = np.array(df['target'].values)
    p = np.array(df['predict'].values)
    mae = abs(y - p).mean()
    std = abs(y - p).std()
    plt.figure(num=None, figsize=(50, 5))
    plt.title('MAE: %.2f, σ: %.2f' % (mae, std), fontsize=30)
    plt.tick_params(labelsize=30)
    plt.plot(y, label='Target')
    plt.plot(p, label='Predict')
    plt.legend(loc=3, prop={'size': 20})
    plt.tight_layout()
    plt.grid()
    # plt.title(mae_2)
    plt.savefig("plot/" + cctv_Id + "/total.png")
    plt.close('all')
    plt.clf()
    plt.cla()
    print("Total MAE: %.3f\n" % mae, file=open(total_name, 'a'))
    print("**********************\n", file=open(total_name, 'a'))
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 50, 72, 106, 1)    0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 50, 36, 53, 32)    896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 36, 53, 32)    128
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 50, 18, 26, 32)    0
# _________________________________________________________________
# activation_1 (Activation)    (None, 50, 18, 26, 32)    0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 50, 18, 26, 32)    27680
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 50, 18, 26, 32)    128
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 25, 9, 13, 32)     0
# _________________________________________________________________
# activation_2 (Activation)    (None, 25, 9, 13, 32)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 25, 9, 13, 32)     27680
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25, 9, 13, 32)     128
# _________________________________________________________________
# activation_3 (Activation)    (None, 25, 9, 13, 32)     0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 25, 3744)          0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 25, 128)           1487232
# _________________________________________________________________
# gru_2 (GRU)                  (None, 25, 128)           98688
# _________________________________________________________________
# gru_3 (GRU)                  (None, 128)               98688
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,741,377
# Trainable params: 1,741,185
# Non-trainable params: 192
# _________________________________________________________________
# nfbCCTV-N5-S-21.048-M
# C3G25
# DatetimeIndex(['2019-07-29 16:41:00', '2019-07-29 16:42:00',
#                '2019-07-29 16:43:00', '2019-07-29 16:44:00',
#                '2019-07-29 16:45:00', '2019-07-29 16:46:00',
#                '2019-07-29 16:47:00', '2019-07-29 16:48:00',
#                '2019-07-29 16:49:00', '2019-07-29 16:50:00',
#                ...
#                '2019-07-30 16:32:00', '2019-07-30 16:33:00',
#                '2019-07-30 16:34:00', '2019-07-30 16:35:00',
#                '2019-07-30 16:36:00', '2019-07-30 16:37:00',
#                '2019-07-30 16:38:00', '2019-07-30 16:39:00',
#                '2019-07-30 16:40:00', '2019-07-30 16:41:00'],
#               dtype='datetime64[ns]', name=0, length=1081, freq=None)
# 2019-08-11 17:25:15.474235
# Frame Num: 1081
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 2/2 [==============================] - 78s 39s/step - loss: 68.7787 - acc: 0.0000e+00 - val_loss: 68.4761 - val_acc: 0.0000e+00
# Epoch 2/100
# 2/2 [==============================] - 29s 15s/step - loss: 68.3839 - acc: 0.0000e+00 - val_loss: 67.7172 - val_acc: 0.0000e+00
# Epoch 3/100
# 2/2 [==============================] - 29s 15s/step - loss: 67.5710 - acc: 0.0000e+00 - val_loss: 66.6554 - val_acc: 0.0000e+00
# Epoch 4/100
# 2/2 [==============================] - 28s 14s/step - loss: 66.4269 - acc: 0.0000e+00 - val_loss: 65.3777 - val_acc: 0.0000e+00
# Epoch 5/100
# 2/2 [==============================] - 28s 14s/step - loss: 65.2486 - acc: 0.0000e+00 - val_loss: 63.9548 - val_acc: 0.0000e+00
# Epoch 6/100
# 2/2 [==============================] - 26s 13s/step - loss: 63.8817 - acc: 0.0000e+00 - val_loss: 62.4397 - val_acc: 0.0000e+00
# Epoch 7/100
# 2/2 [==============================] - 29s 15s/step - loss: 62.4933 - acc: 0.0000e+00 - val_loss: 60.8638 - val_acc: 0.0000e+00
# Epoch 8/100
# 2/2 [==============================] - 31s 16s/step - loss: 60.9119 - acc: 0.0000e+00 - val_loss: 59.2494 - val_acc: 0.0000e+00
# Epoch 9/100
# 2/2 [==============================] - 30s 15s/step - loss: 59.3920 - acc: 0.0000e+00 - val_loss: 57.6079 - val_acc: 0.0000e+00
# Epoch 10/100
# 2/2 [==============================] - 29s 14s/step - loss: 57.7821 - acc: 0.0000e+00 - val_loss: 55.9565 - val_acc: 0.0000e+00
# Epoch 11/100
# 2/2 [==============================] - 29s 15s/step - loss: 56.1163 - acc: 0.0000e+00 - val_loss: 54.2863 - val_acc: 0.0000e+00
# Epoch 12/100
# 2/2 [==============================] - 29s 14s/step - loss: 54.4859 - acc: 0.0000e+00 - val_loss: 52.5922 - val_acc: 0.0156
# Epoch 13/100
# 2/2 [==============================] - 27s 14s/step - loss: 52.8040 - acc: 0.0156 - val_loss: 50.9280 - val_acc: 0.0000e+00
# Epoch 14/100
# 2/2 [==============================] - 29s 14s/step - loss: 51.1709 - acc: 0.0000e+00 - val_loss: 49.2584 - val_acc: 0.0156
# Epoch 15/100
# 2/2 [==============================] - 27s 13s/step - loss: 49.5089 - acc: 0.0156 - val_loss: 47.6101 - val_acc: 0.0000e+00
# Epoch 16/100
# 2/2 [==============================] - 28s 14s/step - loss: 47.8114 - acc: 0.0000e+00 - val_loss: 45.9331 - val_acc: 0.0000e+00
# Epoch 17/100
# 2/2 [==============================] - 27s 14s/step - loss: 46.1003 - acc: 0.0000e+00 - val_loss: 44.2210 - val_acc: 0.0000e+00
# Epoch 18/100
# 2/2 [==============================] - 25s 13s/step - loss: 44.4099 - acc: 0.0000e+00 - val_loss: 42.4925 - val_acc: 0.0000e+00
# Epoch 19/100
# 2/2 [==============================] - 26s 13s/step - loss: 42.6104 - acc: 0.0156 - val_loss: 40.7649 - val_acc: 0.0000e+00
# Epoch 20/100
# 2/2 [==============================] - 30s 15s/step - loss: 40.8503 - acc: 0.0000e+00 - val_loss: 39.0053 - val_acc: 0.0000e+00
# Epoch 21/100
# 2/2 [==============================] - 32s 16s/step - loss: 39.0986 - acc: 0.0000e+00 - val_loss: 37.2334 - val_acc: 0.0000e+00
# Epoch 22/100
# 2/2 [==============================] - 26s 13s/step - loss: 37.3148 - acc: 0.0000e+00 - val_loss: 35.4838 - val_acc: 0.0000e+00
# Epoch 23/100
# 2/2 [==============================] - 27s 13s/step - loss: 35.5385 - acc: 0.0000e+00 - val_loss: 33.7644 - val_acc: 0.0156
# Epoch 24/100
# 2/2 [==============================] - 31s 16s/step - loss: 33.8238 - acc: 0.0312 - val_loss: 32.2354 - val_acc: 0.0156
# Epoch 25/100
# 2/2 [==============================] - 31s 15s/step - loss: 32.2497 - acc: 0.0312 - val_loss: 30.8863 - val_acc: 0.0000e+00
# Epoch 26/100
# 2/2 [==============================] - 31s 16s/step - loss: 30.8784 - acc: 0.0312 - val_loss: 29.7419 - val_acc: 0.0156
# Epoch 27/100
# 2/2 [==============================] - 32s 16s/step - loss: 29.7359 - acc: 0.0312 - val_loss: 28.7149 - val_acc: 0.0000e+00
# Epoch 28/100
# 2/2 [==============================] - 33s 17s/step - loss: 28.6171 - acc: 0.0469 - val_loss: 27.8456 - val_acc: 0.0156
# Epoch 29/100
# 2/2 [==============================] - 34s 17s/step - loss: 27.8559 - acc: 0.0469 - val_loss: 27.1874 - val_acc: 0.0000e+00
# Epoch 30/100
# 2/2 [==============================] - 33s 17s/step - loss: 27.1269 - acc: 0.0000e+00 - val_loss: 26.5322 - val_acc: 0.0000e+00
# Epoch 31/100
# 2/2 [==============================] - 36s 18s/step - loss: 26.5077 - acc: 0.0000e+00 - val_loss: 25.8724 - val_acc: 0.0000e+00
# Epoch 32/100
# 2/2 [==============================] - 38s 19s/step - loss: 25.8130 - acc: 0.0000e+00 - val_loss: 25.2121 - val_acc: 0.0000e+00
# Epoch 33/100
# 2/2 [==============================] - 37s 18s/step - loss: 25.1971 - acc: 0.0000e+00 - val_loss: 24.5513 - val_acc: 0.0000e+00
# Epoch 34/100
# 2/2 [==============================] - 33s 16s/step - loss: 24.4339 - acc: 0.0000e+00 - val_loss: 23.8904 - val_acc: 0.0000e+00
# Epoch 35/100
# 2/2 [==============================] - 34s 17s/step - loss: 23.8095 - acc: 0.0000e+00 - val_loss: 23.2292 - val_acc: 0.0000e+00
# Epoch 36/100
# 2/2 [==============================] - 40s 20s/step - loss: 23.1691 - acc: 0.0000e+00 - val_loss: 22.5666 - val_acc: 0.0156
# Epoch 37/100
# 2/2 [==============================] - 37s 18s/step - loss: 22.5473 - acc: 0.0000e+00 - val_loss: 21.9630 - val_acc: 0.0000e+00
# Epoch 38/100
# 2/2 [==============================] - 43s 22s/step - loss: 21.9588 - acc: 0.0000e+00 - val_loss: 21.3664 - val_acc: 0.0000e+00
# Epoch 39/100
# 2/2 [==============================] - 38s 19s/step - loss: 21.3303 - acc: 0.0156 - val_loss: 20.8060 - val_acc: 0.0000e+00
# Epoch 40/100
# 2/2 [==============================] - 36s 18s/step - loss: 20.7143 - acc: 0.0156 - val_loss: 20.3168 - val_acc: 0.0000e+00
# Epoch 41/100
# 2/2 [==============================] - 39s 20s/step - loss: 20.2233 - acc: 0.0000e+00 - val_loss: 19.8586 - val_acc: 0.0000e+00
# Epoch 42/100
# 2/2 [==============================] - 39s 19s/step - loss: 19.8235 - acc: 0.0000e+00 - val_loss: 19.4146 - val_acc: 0.0156
# Epoch 43/100
# 2/2 [==============================] - 43s 21s/step - loss: 19.3721 - acc: 0.0156 - val_loss: 19.0218 - val_acc: 0.0156
# Epoch 44/100
# 2/2 [==============================] - 39s 19s/step - loss: 18.9480 - acc: 0.0000e+00 - val_loss: 18.6794 - val_acc: 0.0000e+00
# Epoch 45/100
# 2/2 [==============================] - 32s 16s/step - loss: 18.6439 - acc: 0.0000e+00 - val_loss: 18.4456 - val_acc: 0.0781
# Epoch 46/100
# 2/2 [==============================] - 42s 21s/step - loss: 18.4592 - acc: 0.0469 - val_loss: 18.6427 - val_acc: 0.0312
# Epoch 47/100
# 2/2 [==============================] - 43s 21s/step - loss: 18.6747 - acc: 0.0000e+00 - val_loss: 18.8648 - val_acc: 0.0781
# Epoch 48/100
# 2/2 [==============================] - 38s 19s/step - loss: 18.8461 - acc: 0.0312 - val_loss: 19.0201 - val_acc: 0.0781
# Epoch 49/100
# 2/2 [==============================] - 33s 17s/step - loss: 18.9680 - acc: 0.0781 - val_loss: 19.0365 - val_acc: 0.0781
# Epoch 50/100
# 2/2 [==============================] - 31s 15s/step - loss: 18.9074 - acc: 0.0625 - val_loss: 18.9142 - val_acc: 0.0781
# Epoch 51/100
# 2/2 [==============================] - 29s 15s/step - loss: 18.8105 - acc: 0.0469 - val_loss: 18.7636 - val_acc: 0.0312
# Epoch 52/100
# 2/2 [==============================] - 31s 15s/step - loss: 18.6480 - acc: 0.0156 - val_loss: 18.6096 - val_acc: 0.0156
# Epoch 53/100
# 2/2 [==============================] - 32s 16s/step - loss: 18.5462 - acc: 0.0156 - val_loss: 18.4674 - val_acc: 0.0781
# Epoch 54/100
# 2/2 [==============================] - 35s 18s/step - loss: 18.4171 - acc: 0.0625 - val_loss: 18.4588 - val_acc: 0.0625
# Epoch 55/100
# 2/2 [==============================] - 30s 15s/step - loss: 18.4911 - acc: 0.0625 - val_loss: 18.4996 - val_acc: 0.0625
# 2/2 [==============================] - 13s 6s/step
# 17
# 20
# Epoch 1/100
# 8/8 [==============================] - 117s 15s/step - loss: 43.8729 - acc: 0.0000e+00 - val_loss: 41.5515 - val_acc: 0.0039
# Epoch 2/100
# 8/8 [==============================] - 125s 16s/step - loss: 38.4053 - acc: 0.0000e+00 - val_loss: 34.7998 - val_acc: 0.0000e+00
# Epoch 3/100
# 8/8 [==============================] - 120s 15s/step - loss: 31.2720 - acc: 0.0000e+00 - val_loss: 27.3956 - val_acc: 0.0000e+00
# Epoch 4/100
# 8/8 [==============================] - 121s 15s/step - loss: 23.4032 - acc: 0.0000e+00 - val_loss: 19.3008 - val_acc: 0.0000e+00
# Epoch 5/100
# 8/8 [==============================] - 132s 17s/step - loss: 15.3932 - acc: 0.0000e+00 - val_loss: 11.1642 - val_acc: 0.0273
# Epoch 6/100
# 8/8 [==============================] - 127s 16s/step - loss: 8.6690 - acc: 0.0625 - val_loss: 7.0864 - val_acc: 0.0859
# Epoch 7/100
# 8/8 [==============================] - 120s 15s/step - loss: 7.4308 - acc: 0.0664 - val_loss: 7.5237 - val_acc: 0.0469
# Epoch 8/100
# 8/8 [==============================] - 119s 15s/step - loss: 7.3707 - acc: 0.0547 - val_loss: 7.1018 - val_acc: 0.0859
# Epoch 9/100
# 8/8 [==============================] - 119s 15s/step - loss: 7.2299 - acc: 0.0430 - val_loss: 7.2099 - val_acc: 0.0508
# Epoch 10/100
# 8/8 [==============================] - 118s 15s/step - loss: 7.1199 - acc: 0.0586 - val_loss: 7.0921 - val_acc: 0.0859
# Epoch 11/100
# 8/8 [==============================] - 123s 15s/step - loss: 7.0782 - acc: 0.0781 - val_loss: 7.1217 - val_acc: 0.0859
# Epoch 12/100
# 8/8 [==============================] - 127s 16s/step - loss: 7.0728 - acc: 0.0859 - val_loss: 7.0980 - val_acc: 0.0859
# Epoch 13/100
# 8/8 [==============================] - 123s 15s/step - loss: 7.0828 - acc: 0.0781 - val_loss: 7.1080 - val_acc: 0.0859
# Epoch 14/100
# 8/8 [==============================] - 118s 15s/step - loss: 7.1193 - acc: 0.0898 - val_loss: 7.1239 - val_acc: 0.0859
# Epoch 15/100
# 8/8 [==============================] - 119s 15s/step - loss: 7.0861 - acc: 0.0898 - val_loss: 7.1019 - val_acc: 0.0859
# Epoch 16/100
# 8/8 [==============================] - 119s 15s/step - loss: 7.0934 - acc: 0.0820 - val_loss: 7.1088 - val_acc: 0.0859
# 8/8 [==============================] - 40s 5s/step
# 3
# 8/8 [==============================] - 40s 5s/step
# 2
# 9/9 [==============================] - 45s 5s/step
# 6
# 8/8 [==============================] - 40s 5s/step
# nfbCCTV-N5-S-23.896-M
# C3G25
# DatetimeIndex(['2019-07-29 16:41:00', '2019-07-29 16:42:00',
#                '2019-07-29 16:43:00', '2019-07-29 16:44:00',
#                '2019-07-29 16:45:00', '2019-07-29 16:46:00',
#                '2019-07-29 16:47:00', '2019-07-29 16:48:00',
#                '2019-07-29 16:49:00', '2019-07-29 16:50:00',
#                ...
#                '2019-07-30 16:32:00', '2019-07-30 16:33:00',
#                '2019-07-30 16:34:00', '2019-07-30 16:35:00',
#                '2019-07-30 16:36:00', '2019-07-30 16:37:00',
#                '2019-07-30 16:38:00', '2019-07-30 16:39:00',
#                '2019-07-30 16:40:00', '2019-07-30 16:41:00'],
#               dtype='datetime64[ns]', name=0, length=1081, freq=None)
# 2019-08-11 18:31:41.926478
# Frame Num: 1081
# Epoch 1/100
# 2/2 [==============================] - 28s 14s/step - loss: 32.0733 - acc: 0.0312 - val_loss: 31.7116 - val_acc: 0.0156
# Epoch 2/100
# 2/2 [==============================] - 24s 12s/step - loss: 31.8792 - acc: 0.0000e+00 - val_loss: 31.3551 - val_acc: 0.0000e+00
# Epoch 3/100
# 2/2 [==============================] - 24s 12s/step - loss: 31.4459 - acc: 0.0156 - val_loss: 30.8179 - val_acc: 0.0000e+00
# Epoch 4/100
# 2/2 [==============================] - 24s 12s/step - loss: 30.8386 - acc: 0.0156 - val_loss: 30.1846 - val_acc: 0.0625
# Epoch 5/100
# 2/2 [==============================] - 25s 12s/step - loss: 30.2336 - acc: 0.0312 - val_loss: 29.5420 - val_acc: 0.0156
# Epoch 6/100
# 2/2 [==============================] - 24s 12s/step - loss: 29.4820 - acc: 0.0156 - val_loss: 28.8736 - val_acc: 0.0156
# Epoch 7/100
# 2/2 [==============================] - 26s 13s/step - loss: 28.8001 - acc: 0.0312 - val_loss: 28.2172 - val_acc: 0.0156
# Epoch 8/100
# 2/2 [==============================] - 29s 15s/step - loss: 28.1176 - acc: 0.0156 - val_loss: 27.6054 - val_acc: 0.0312
# Epoch 9/100
# 2/2 [==============================] - 29s 15s/step - loss: 27.5502 - acc: 0.0312 - val_loss: 27.0957 - val_acc: 0.0000e+00
# Epoch 10/100
# 2/2 [==============================] - 29s 15s/step - loss: 27.0876 - acc: 0.0000e+00 - val_loss: 26.5892 - val_acc: 0.0000e+00
# Epoch 11/100
# 2/2 [==============================] - 29s 15s/step - loss: 26.5724 - acc: 0.0000e+00 - val_loss: 26.0661 - val_acc: 0.0000e+00
# Epoch 12/100
# 2/2 [==============================] - 29s 15s/step - loss: 25.9648 - acc: 0.0000e+00 - val_loss: 25.5311 - val_acc: 0.0000e+00
# Epoch 13/100
# 2/2 [==============================] - 30s 15s/step - loss: 25.3942 - acc: 0.0000e+00 - val_loss: 24.9837 - val_acc: 0.0000e+00
# Epoch 14/100
# 2/2 [==============================] - 29s 15s/step - loss: 24.8914 - acc: 0.0000e+00 - val_loss: 24.4299 - val_acc: 0.0000e+00
# Epoch 15/100
# 2/2 [==============================] - 29s 15s/step - loss: 24.3971 - acc: 0.0000e+00 - val_loss: 23.8664 - val_acc: 0.0000e+00
# Epoch 16/100
# 2/2 [==============================] - 29s 15s/step - loss: 23.8496 - acc: 0.0000e+00 - val_loss: 23.2950 - val_acc: 0.0000e+00
# Epoch 17/100
# 2/2 [==============================] - 29s 15s/step - loss: 23.2380 - acc: 0.0000e+00 - val_loss: 22.6964 - val_acc: 0.0000e+00
# Epoch 18/100
# 2/2 [==============================] - 29s 15s/step - loss: 22.5751 - acc: 0.0000e+00 - val_loss: 22.1060 - val_acc: 0.0000e+00
# Epoch 19/100
# 2/2 [==============================] - 29s 15s/step - loss: 21.9749 - acc: 0.0000e+00 - val_loss: 21.5260 - val_acc: 0.0156
# Epoch 20/100
# 2/2 [==============================] - 29s 15s/step - loss: 21.4257 - acc: 0.0312 - val_loss: 21.0457 - val_acc: 0.0000e+00
# Epoch 21/100
# 2/2 [==============================] - 29s 15s/step - loss: 20.9189 - acc: 0.0156 - val_loss: 20.6331 - val_acc: 0.0000e+00
# Epoch 22/100
# 2/2 [==============================] - 29s 15s/step - loss: 20.6142 - acc: 0.0000e+00 - val_loss: 20.2533 - val_acc: 0.0000e+00
# Epoch 23/100
# 2/2 [==============================] - 29s 15s/step - loss: 20.1538 - acc: 0.0000e+00 - val_loss: 19.8956 - val_acc: 0.0156
# Epoch 24/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.9356 - acc: 0.0156 - val_loss: 19.6411 - val_acc: 0.0000e+00
# Epoch 25/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.6346 - acc: 0.0000e+00 - val_loss: 19.4607 - val_acc: 0.0000e+00
# Epoch 26/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.4783 - acc: 0.0000e+00 - val_loss: 19.3700 - val_acc: 0.0469
# Epoch 27/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3986 - acc: 0.0156 - val_loss: 19.4523 - val_acc: 0.0469
# Epoch 28/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.4258 - acc: 0.0781 - val_loss: 19.6274 - val_acc: 0.0469
# Epoch 29/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.6148 - acc: 0.0469 - val_loss: 19.7355 - val_acc: 0.0469
# Epoch 30/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.6698 - acc: 0.0312 - val_loss: 19.7214 - val_acc: 0.0469
# Epoch 31/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.6454 - acc: 0.0469 - val_loss: 19.6112 - val_acc: 0.0469
# Epoch 32/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.5450 - acc: 0.0312 - val_loss: 19.4883 - val_acc: 0.0469
# Epoch 33/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3907 - acc: 0.0469 - val_loss: 19.3934 - val_acc: 0.0469
# Epoch 34/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3774 - acc: 0.0469 - val_loss: 19.3688 - val_acc: 0.0469
# Epoch 35/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3557 - acc: 0.0156 - val_loss: 19.3890 - val_acc: 0.0156
# Epoch 36/100
# 2/2 [==============================] - 30s 15s/step - loss: 19.3818 - acc: 0.0156 - val_loss: 19.4111 - val_acc: 0.0156
# Epoch 37/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.4411 - acc: 0.0000e+00 - val_loss: 19.4186 - val_acc: 0.0156
# Epoch 38/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.4329 - acc: 0.0000e+00 - val_loss: 19.4086 - val_acc: 0.0156
# Epoch 39/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.4514 - acc: 0.0156 - val_loss: 19.3951 - val_acc: 0.0156
# Epoch 40/100
# 2/2 [==============================] - 29s 14s/step - loss: 19.4152 - acc: 0.0156 - val_loss: 19.3812 - val_acc: 0.0156
# Epoch 41/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3926 - acc: 0.0156 - val_loss: 19.3666 - val_acc: 0.0469
# Epoch 42/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3758 - acc: 0.0469 - val_loss: 19.3726 - val_acc: 0.0469
# Epoch 43/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.4009 - acc: 0.0312 - val_loss: 19.4073 - val_acc: 0.0469
# Epoch 44/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3514 - acc: 0.0938 - val_loss: 19.4344 - val_acc: 0.0469
# Epoch 45/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.4421 - acc: 0.0312 - val_loss: 19.4599 - val_acc: 0.0469
# Epoch 46/100
# 2/2 [==============================] - 30s 15s/step - loss: 19.4256 - acc: 0.0469 - val_loss: 19.4303 - val_acc: 0.0469
# Epoch 47/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3975 - acc: 0.0469 - val_loss: 19.4014 - val_acc: 0.0469
# Epoch 48/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3791 - acc: 0.0156 - val_loss: 19.3636 - val_acc: 0.0469
# Epoch 49/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.4077 - acc: 0.0312 - val_loss: 19.3699 - val_acc: 0.0469
# Epoch 50/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3797 - acc: 0.0156 - val_loss: 19.3776 - val_acc: 0.0156
# Epoch 51/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.4304 - acc: 0.0156 - val_loss: 19.3801 - val_acc: 0.0156
# Epoch 52/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.4053 - acc: 0.0156 - val_loss: 19.3791 - val_acc: 0.0156
# Epoch 53/100
# 2/2 [==============================] - 30s 15s/step - loss: 19.3827 - acc: 0.0156 - val_loss: 19.3744 - val_acc: 0.0156
# Epoch 54/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3396 - acc: 0.0156 - val_loss: 19.3672 - val_acc: 0.0469
# Epoch 55/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3830 - acc: 0.0156 - val_loss: 19.3566 - val_acc: 0.0469
# Epoch 56/100
# 2/2 [==============================] - 30s 15s/step - loss: 19.3552 - acc: 0.0469 - val_loss: 19.3789 - val_acc: 0.0469
# Epoch 57/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3451 - acc: 0.0469 - val_loss: 19.3917 - val_acc: 0.0469
# Epoch 58/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3507 - acc: 0.0625 - val_loss: 19.3920 - val_acc: 0.0469
# Epoch 59/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3533 - acc: 0.0469 - val_loss: 19.3803 - val_acc: 0.0469
# Epoch 60/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3482 - acc: 0.0469 - val_loss: 19.3624 - val_acc: 0.0469
# Epoch 61/100
# 2/2 [==============================] - 29s 14s/step - loss: 19.3800 - acc: 0.0312 - val_loss: 19.3582 - val_acc: 0.0469
# Epoch 62/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3554 - acc: 0.0469 - val_loss: 19.3587 - val_acc: 0.0469
# Epoch 63/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3489 - acc: 0.0469 - val_loss: 19.3652 - val_acc: 0.0469
# Epoch 64/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3740 - acc: 0.0469 - val_loss: 19.3723 - val_acc: 0.0469
# Epoch 65/100
# 2/2 [==============================] - 29s 15s/step - loss: 19.3904 - acc: 0.0469 - val_loss: 19.3752 - val_acc: 0.0469
# 2/2 [==============================] - 11s 6s/step
# 17
# 2/2 [==============================] - 10s 5s/step
# 20
# Epoch 1/100
# 8/8 [==============================] - 127s 16s/step - loss: 43.0502 - acc: 0.0039 - val_loss: 41.0590 - val_acc: 0.0000e+00
# Epoch 2/100
# 8/8 [==============================] - 117s 15s/step - loss: 38.0654 - acc: 0.0000e+00 - val_loss: 34.9023 - val_acc: 0.0000e+00
# Epoch 3/100
# 8/8 [==============================] - 117s 15s/step - loss: 31.2963 - acc: 0.0000e+00 - val_loss: 27.4124 - val_acc: 0.0000e+00
# Epoch 4/100
# 8/8 [==============================] - 117s 15s/step - loss: 23.7184 - acc: 0.0000e+00 - val_loss: 19.6240 - val_acc: 0.0000e+00
# Epoch 5/100
# 8/8 [==============================] - 117s 15s/step - loss: 15.3806 - acc: 0.0039 - val_loss: 10.9779 - val_acc: 0.0273
# Epoch 6/100
# 8/8 [==============================] - 117s 15s/step - loss: 8.3130 - acc: 0.0391 - val_loss: 7.6535 - val_acc: 0.0547
# Epoch 7/100
# 8/8 [==============================] - 117s 15s/step - loss: 8.3250 - acc: 0.0352 - val_loss: 7.6399 - val_acc: 0.0547
# Epoch 8/100
# 8/8 [==============================] - 118s 15s/step - loss: 7.5637 - acc: 0.0469 - val_loss: 7.4996 - val_acc: 0.0469
# Epoch 9/100
# 8/8 [==============================] - 121s 15s/step - loss: 7.4437 - acc: 0.0508 - val_loss: 7.3951 - val_acc: 0.0664
# Epoch 10/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.3797 - acc: 0.0820 - val_loss: 7.3604 - val_acc: 0.0703
# Epoch 11/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.3406 - acc: 0.0625 - val_loss: 7.3991 - val_acc: 0.0469
# Epoch 12/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.4077 - acc: 0.0703 - val_loss: 7.3528 - val_acc: 0.0703
# Epoch 13/100
# 8/8 [==============================] - 118s 15s/step - loss: 7.3676 - acc: 0.0586 - val_loss: 7.3736 - val_acc: 0.0703
# Epoch 14/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.3831 - acc: 0.0742 - val_loss: 7.3575 - val_acc: 0.0703
# Epoch 15/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.3229 - acc: 0.0664 - val_loss: 7.3512 - val_acc: 0.0703
# Epoch 16/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.3705 - acc: 0.0586 - val_loss: 7.3369 - val_acc: 0.0703
# Epoch 17/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.3336 - acc: 0.0664 - val_loss: 7.3611 - val_acc: 0.0781
# Epoch 18/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.3035 - acc: 0.0664 - val_loss: 7.3096 - val_acc: 0.0742
# Epoch 19/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.2853 - acc: 0.0781 - val_loss: 7.2816 - val_acc: 0.0820
# Epoch 20/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.2917 - acc: 0.0664 - val_loss: 7.2685 - val_acc: 0.0781
# Epoch 21/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.2450 - acc: 0.0664 - val_loss: 7.2768 - val_acc: 0.0664
# Epoch 22/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.1855 - acc: 0.0586 - val_loss: 7.1920 - val_acc: 0.0625
# Epoch 23/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.2725 - acc: 0.0430 - val_loss: 7.1572 - val_acc: 0.0625
# Epoch 24/100
# 8/8 [==============================] - 118s 15s/step - loss: 7.1574 - acc: 0.0586 - val_loss: 7.1365 - val_acc: 0.0508
# Epoch 25/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.1671 - acc: 0.0742 - val_loss: 7.1652 - val_acc: 0.0586
# Epoch 26/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.1583 - acc: 0.0898 - val_loss: 7.3459 - val_acc: 0.0547
# Epoch 27/100
# 8/8 [==============================] - 117s 15s/step - loss: 7.1412 - acc: 0.0625 - val_loss: 7.1519 - val_acc: 0.0664
# Epoch 28/100
# 8/8 [==============================] - 125s 16s/step - loss: 7.1267 - acc: 0.0820 - val_loss: 7.3443 - val_acc: 0.0508
# Epoch 29/100
# 8/8 [==============================] - 125s 16s/step - loss: 7.1324 - acc: 0.0586 - val_loss: 7.1838 - val_acc: 0.0664
# Epoch 30/100
# 8/8 [==============================] - 125s 16s/step - loss: 7.0931 - acc: 0.0664 - val_loss: 7.1341 - val_acc: 0.0664
# Epoch 31/100
# 8/8 [==============================] - 178s 22s/step - loss: 7.1279 - acc: 0.0742 - val_loss: 7.1571 - val_acc: 0.0625
# Epoch 32/100
# 8/8 [==============================] - 204s 25s/step - loss: 7.1554 - acc: 0.0547 - val_loss: 7.1146 - val_acc: 0.0586
# Epoch 33/100
# 8/8 [==============================] - 191s 24s/step - loss: 7.2087 - acc: 0.0430 - val_loss: 7.0935 - val_acc: 0.0664
# Epoch 34/100
# 8/8 [==============================] - 149s 19s/step - loss: 7.0857 - acc: 0.0703 - val_loss: 7.0751 - val_acc: 0.0664
# Epoch 35/100
# 8/8 [==============================] - 141s 18s/step - loss: 7.0926 - acc: 0.0664 - val_loss: 7.0892 - val_acc: 0.0703
# Epoch 36/100
# 8/8 [==============================] - 129s 16s/step - loss: 7.0831 - acc: 0.0820 - val_loss: 7.1131 - val_acc: 0.0703
# Epoch 37/100
# 8/8 [==============================] - 146s 18s/step - loss: 7.1279 - acc: 0.0781 - val_loss: 7.0680 - val_acc: 0.0664
# Epoch 38/100
# 8/8 [==============================] - 144s 18s/step - loss: 7.1562 - acc: 0.0664 - val_loss: 7.1011 - val_acc: 0.0859
# Epoch 39/100
# 8/8 [==============================] - 134s 17s/step - loss: 7.1423 - acc: 0.0742 - val_loss: 7.2409 - val_acc: 0.0586
# Epoch 40/100
# 8/8 [==============================] - 131s 16s/step - loss: 7.0493 - acc: 0.0508 - val_loss: 7.3988 - val_acc: 0.0664
# Epoch 41/100
# 8/8 [==============================] - 130s 16s/step - loss: 7.1103 - acc: 0.0859 - val_loss: 7.2572 - val_acc: 0.0508
# Epoch 42/100
# 8/8 [==============================] - 123s 15s/step - loss: 7.0419 - acc: 0.0781 - val_loss: 7.1398 - val_acc: 0.0586
# Epoch 43/100
# 8/8 [==============================] - 126s 16s/step - loss: 7.0844 - acc: 0.0430 - val_loss: 6.9870 - val_acc: 0.0898
# Epoch 44/100
# 8/8 [==============================] - 131s 16s/step - loss: 6.9993 - acc: 0.1016 - val_loss: 7.2130 - val_acc: 0.0703
# Epoch 45/100
# 8/8 [==============================] - 133s 17s/step - loss: 7.0709 - acc: 0.0781 - val_loss: 7.2283 - val_acc: 0.0703
# Epoch 46/100
# 8/8 [==============================] - 129s 16s/step - loss: 6.9785 - acc: 0.0703 - val_loss: 7.4448 - val_acc: 0.0742
# Epoch 47/100
# 8/8 [==============================] - 122s 15s/step - loss: 6.9306 - acc: 0.0742 - val_loss: 7.0884 - val_acc: 0.0508
# Epoch 48/100
# 8/8 [==============================] - 123s 15s/step - loss: 6.9535 - acc: 0.0820 - val_loss: 7.8766 - val_acc: 0.0352
# Epoch 49/100
# 8/8 [==============================] - 127s 16s/step - loss: 6.9874 - acc: 0.0586 - val_loss: 6.8920 - val_acc: 0.0898
# Epoch 50/100
# 8/8 [==============================] - 121s 15s/step - loss: 6.8229 - acc: 0.0859 - val_loss: 6.8951 - val_acc: 0.0625
# Epoch 51/100
# 8/8 [==============================] - 122s 15s/step - loss: 7.0873 - acc: 0.0547 - val_loss: 6.8656 - val_acc: 0.1055
# Epoch 52/100
# 8/8 [==============================] - 126s 16s/step - loss: 7.0103 - acc: 0.1016 - val_loss: 6.8508 - val_acc: 0.0703
# Epoch 53/100
# 8/8 [==============================] - 133s 17s/step - loss: 6.9364 - acc: 0.0859 - val_loss: 6.7978 - val_acc: 0.0820
# Epoch 54/100
# 8/8 [==============================] - 129s 16s/step - loss: 6.8731 - acc: 0.0742 - val_loss: 6.8483 - val_acc: 0.0977
# Epoch 55/100
# 8/8 [==============================] - 125s 16s/step - loss: 6.8282 - acc: 0.0742 - val_loss: 7.2465 - val_acc: 0.0664
# Epoch 56/100
# 8/8 [==============================] - 124s 16s/step - loss: 6.8731 - acc: 0.0820 - val_loss: 6.6443 - val_acc: 0.1094
# Epoch 57/100
# 8/8 [==============================] - 135s 17s/step - loss: 6.9537 - acc: 0.0664 - val_loss: 6.7741 - val_acc: 0.0938
# Epoch 58/100
# 8/8 [==============================] - 125s 16s/step - loss: 6.7741 - acc: 0.0430 - val_loss: 6.9877 - val_acc: 0.0312
# Epoch 59/100
# 8/8 [==============================] - 124s 16s/step - loss: 6.8799 - acc: 0.0586 - val_loss: 7.8688 - val_acc: 0.0508
# Epoch 60/100
# 8/8 [==============================] - 129s 16s/step - loss: 6.8703 - acc: 0.0430 - val_loss: 6.6231 - val_acc: 0.1094
# Epoch 61/100
# 8/8 [==============================] - 123s 15s/step - loss: 6.6415 - acc: 0.0703 - val_loss: 6.7847 - val_acc: 0.0859
# Epoch 62/100
# 8/8 [==============================] - 132s 16s/step - loss: 6.7762 - acc: 0.0586 - val_loss: 7.6695 - val_acc: 0.0703
# Epoch 63/100
# 8/8 [==============================] - 131s 16s/step - loss: 6.6605 - acc: 0.0625 - val_loss: 6.8775 - val_acc: 0.0547
# Epoch 64/100
# 8/8 [==============================] - 122s 15s/step - loss: 6.5862 - acc: 0.1055 - val_loss: 7.5963 - val_acc: 0.0547
# Epoch 65/100
# 8/8 [==============================] - 123s 15s/step - loss: 6.5651 - acc: 0.0586 - val_loss: 7.9805 - val_acc: 0.0781
# Epoch 66/100
# 8/8 [==============================] - 121s 15s/step - loss: 6.6935 - acc: 0.0938 - val_loss: 6.6525 - val_acc: 0.0820
# Epoch 67/100
# 8/8 [==============================] - 122s 15s/step - loss: 6.8454 - acc: 0.0742 - val_loss: 6.3566 - val_acc: 0.1016
# Epoch 68/100
# 8/8 [==============================] - 125s 16s/step - loss: 6.6832 - acc: 0.0625 - val_loss: 9.6635 - val_acc: 0.0234
# Epoch 69/100
# 8/8 [==============================] - 127s 16s/step - loss: 6.7622 - acc: 0.1133 - val_loss: 6.4973 - val_acc: 0.0742
# Epoch 70/100
# 8/8 [==============================] - 125s 16s/step - loss: 6.7311 - acc: 0.0547 - val_loss: 7.5346 - val_acc: 0.0664
# Epoch 71/100
# 8/8 [==============================] - 124s 16s/step - loss: 6.7251 - acc: 0.0703 - val_loss: 6.2385 - val_acc: 0.0977
# Epoch 72/100
# 8/8 [==============================] - 126s 16s/step - loss: 6.3858 - acc: 0.0781 - val_loss: 6.8741 - val_acc: 0.0820
# Epoch 73/100
# 8/8 [==============================] - 125s 16s/step - loss: 6.2351 - acc: 0.0977 - val_loss: 6.1613 - val_acc: 0.0977
# Epoch 74/100
# 8/8 [==============================] - 124s 15s/step - loss: 6.3999 - acc: 0.0703 - val_loss: 7.9288 - val_acc: 0.0703
# Epoch 75/100
# 8/8 [==============================] - 124s 15s/step - loss: 6.3969 - acc: 0.0781 - val_loss: 7.4303 - val_acc: 0.0820
# Epoch 76/100
# 8/8 [==============================] - 123s 15s/step - loss: 6.2499 - acc: 0.1055 - val_loss: 7.8993 - val_acc: 0.0703
# Epoch 77/100
# 8/8 [==============================] - 124s 15s/step - loss: 6.1621 - acc: 0.1055 - val_loss: 6.1436 - val_acc: 0.0938
# Epoch 78/100
# 8/8 [==============================] - 124s 15s/step - loss: 6.2198 - acc: 0.1016 - val_loss: 6.1352 - val_acc: 0.0820
# Epoch 79/100
# 8/8 [==============================] - 122s 15s/step - loss: 6.2619 - acc: 0.0898 - val_loss: 5.9400 - val_acc: 0.1094
# Epoch 80/100
# 8/8 [==============================] - 124s 15s/step - loss: 6.0240 - acc: 0.0938 - val_loss: 6.6539 - val_acc: 0.0508
# Epoch 81/100
# 8/8 [==============================] - 124s 15s/step - loss: 5.9309 - acc: 0.0859 - val_loss: 7.5899 - val_acc: 0.0742
# Epoch 82/100
# 8/8 [==============================] - 128s 16s/step - loss: 6.2955 - acc: 0.0469 - val_loss: 7.6028 - val_acc: 0.0469
# Epoch 83/100
# 8/8 [==============================] - 127s 16s/step - loss: 5.9811 - acc: 0.0938 - val_loss: 6.3194 - val_acc: 0.0820
# Epoch 84/100
# 8/8 [==============================] - 126s 16s/step - loss: 6.5586 - acc: 0.0625 - val_loss: 6.1783 - val_acc: 0.0820
# Epoch 85/100
# 8/8 [==============================] - 153s 19s/step - loss: 6.2124 - acc: 0.0898 - val_loss: 12.7899 - val_acc: 0.0117
# Epoch 86/100
# 8/8 [==============================] - 155s 19s/step - loss: 6.5130 - acc: 0.0938 - val_loss: 5.6670 - val_acc: 0.1094
# Epoch 87/100
# 8/8 [==============================] - 147s 18s/step - loss: 6.0162 - acc: 0.0859 - val_loss: 8.0538 - val_acc: 0.0781
# Epoch 88/100
# 8/8 [==============================] - 131s 16s/step - loss: 5.9984 - acc: 0.0781 - val_loss: 8.0533 - val_acc: 0.0781
# Epoch 89/100
# 8/8 [==============================] - 158s 20s/step - loss: 5.8777 - acc: 0.0938 - val_loss: 6.1940 - val_acc: 0.0703
# Epoch 90/100
# 8/8 [==============================] - 157s 20s/step - loss: 5.7320 - acc: 0.1367 - val_loss: 12.3352 - val_acc: 0.0156
# Epoch 91/100
# 8/8 [==============================] - 155s 19s/step - loss: 5.8266 - acc: 0.0938 - val_loss: 5.4155 - val_acc: 0.0859
# Epoch 92/100
# 8/8 [==============================] - 129s 16s/step - loss: 5.7568 - acc: 0.1055 - val_loss: 6.3098 - val_acc: 0.0703
# Epoch 93/100
# 8/8 [==============================] - 128s 16s/step - loss: 6.4484 - acc: 0.0586 - val_loss: 5.2583 - val_acc: 0.1211
# Epoch 94/100
# 8/8 [==============================] - 128s 16s/step - loss: 5.6152 - acc: 0.1211 - val_loss: 8.0494 - val_acc: 0.0703
# Epoch 95/100
# 8/8 [==============================] - 123s 15s/step - loss: 5.4344 - acc: 0.1172 - val_loss: 10.5190 - val_acc: 0.0156
# Epoch 96/100
# 8/8 [==============================] - 132s 17s/step - loss: 5.7779 - acc: 0.0898 - val_loss: 5.5090 - val_acc: 0.0898
# Epoch 97/100
# 8/8 [==============================] - 124s 16s/step - loss: 5.7779 - acc: 0.0977 - val_loss: 6.8623 - val_acc: 0.0664
# Epoch 98/100
# 8/8 [==============================] - 125s 16s/step - loss: 5.5788 - acc: 0.0898 - val_loss: 12.8300 - val_acc: 0.0039
# Epoch 99/100
# 8/8 [==============================] - 125s 16s/step - loss: 5.6465 - acc: 0.0938 - val_loss: 4.9818 - val_acc: 0.1172
# Epoch 100/100
# 8/8 [==============================] - 124s 15s/step - loss: 5.4044 - acc: 0.0859 - val_loss: 8.3100 - val_acc: 0.0469
# 8/8 [==============================] - 42s 5s/step
# 3
# 8/8 [==============================] - 41s 5s/step
# 6
# 8/8 [==============================] - 41s 5s/step
# nfbCCTV-N5-N-25.309-M
# C3G25
# DatetimeIndex(['2019-07-29 16:41:00', '2019-07-29 16:42:00',
#                '2019-07-29 16:43:00', '2019-07-29 16:44:00',
#                '2019-07-29 16:45:00', '2019-07-29 16:46:00',
#                '2019-07-29 16:47:00', '2019-07-29 16:48:00',
#                '2019-07-29 16:49:00', '2019-07-29 16:50:00',
#                ...
#                '2019-07-30 16:32:00', '2019-07-30 16:33:00',
#                '2019-07-30 16:34:00', '2019-07-30 16:35:00',
#                '2019-07-30 16:36:00', '2019-07-30 16:37:00',
#                '2019-07-30 16:38:00', '2019-07-30 16:39:00',
#                '2019-07-30 16:40:00', '2019-07-30 16:41:00'],
#               dtype='datetime64[ns]', name=0, length=1081, freq=None)
# 2019-08-11 22:39:23.796362
# Frame Num: 1081
# Epoch 1/100
# 2/2 [==============================] - 35s 17s/step - loss: 33.1077 - acc: 0.0156 - val_loss: 32.2111 - val_acc: 0.0000e+00
# Epoch 2/100
# 2/2 [==============================] - 30s 15s/step - loss: 32.4136 - acc: 0.0156 - val_loss: 31.9456 - val_acc: 0.0000e+00
# Epoch 3/100
# 2/2 [==============================] - 30s 15s/step - loss: 32.0298 - acc: 0.0156 - val_loss: 31.5275 - val_acc: 0.0156
# Epoch 4/100
# 2/2 [==============================] - 31s 15s/step - loss: 31.4950 - acc: 0.0156 - val_loss: 30.9430 - val_acc: 0.0156
# Epoch 5/100
# 2/2 [==============================] - 37s 18s/step - loss: 30.8279 - acc: 0.0156 - val_loss: 30.2823 - val_acc: 0.0312
# Epoch 6/100
# 2/2 [==============================] - 38s 19s/step - loss: 30.3301 - acc: 0.0156 - val_loss: 29.5924 - val_acc: 0.0156
# Epoch 7/100
# 2/2 [==============================] - 30s 15s/step - loss: 29.7513 - acc: 0.0000e+00 - val_loss: 28.5821 - val_acc: 0.0156
# Epoch 8/100
# 2/2 [==============================] - 31s 15s/step - loss: 29.0570 - acc: 0.0000e+00 - val_loss: 27.6559 - val_acc: 0.0312
# Epoch 9/100
# 2/2 [==============================] - 31s 16s/step - loss: 28.1849 - acc: 0.0000e+00 - val_loss: 36.4399 - val_acc: 0.0156
# Epoch 10/100
# 2/2 [==============================] - 30s 15s/step - loss: 26.8979 - acc: 0.0000e+00 - val_loss: 41.1297 - val_acc: 0.0000e+00
# Epoch 11/100
# 2/2 [==============================] - 30s 15s/step - loss: 25.6951 - acc: 0.0156 - val_loss: 41.7084 - val_acc: 0.0000e+00
# Epoch 12/100
# 2/2 [==============================] - 30s 15s/step - loss: 24.9632 - acc: 0.0000e+00 - val_loss: 41.3915 - val_acc: 0.0000e+00
# Epoch 13/100
# 2/2 [==============================] - 31s 16s/step - loss: 24.2123 - acc: 0.0312 - val_loss: 39.7695 - val_acc: 0.0000e+00
# Epoch 14/100
# 2/2 [==============================] - 30s 15s/step - loss: 23.5814 - acc: 0.0156 - val_loss: 37.0322 - val_acc: 0.0000e+00
# Epoch 15/100
# 2/2 [==============================] - 30s 15s/step - loss: 22.7548 - acc: 0.0000e+00 - val_loss: 24.2469 - val_acc: 0.0156
# Epoch 16/100
# 2/2 [==============================] - 31s 15s/step - loss: 22.2461 - acc: 0.0000e+00 - val_loss: 21.2417 - val_acc: 0.0312
# Epoch 17/100
# 2/2 [==============================] - 30s 15s/step - loss: 21.8395 - acc: 0.0000e+00 - val_loss: 20.6757 - val_acc: 0.0000e+00
# Epoch 18/100
# 2/2 [==============================] - 30s 15s/step - loss: 21.2694 - acc: 0.0000e+00 - val_loss: 19.9879 - val_acc: 0.0000e+00
# Epoch 19/100
# 2/2 [==============================] - 30s 15s/step - loss: 20.1665 - acc: 0.0156 - val_loss: 20.2136 - val_acc: 0.0156
# Epoch 20/100
# 2/2 [==============================] - 31s 15s/step - loss: 19.6816 - acc: 0.0312 - val_loss: 22.9848 - val_acc: 0.0156
# Epoch 21/100
# 2/2 [==============================] - 32s 16s/step - loss: 19.0300 - acc: 0.0000e+00 - val_loss: 20.2364 - val_acc: 0.0156
# Epoch 22/100
# 2/2 [==============================] - 36s 18s/step - loss: 18.2025 - acc: 0.0312 - val_loss: 17.3555 - val_acc: 0.0000e+00
# Epoch 23/100
# 2/2 [==============================] - 39s 20s/step - loss: 17.5423 - acc: 0.0000e+00 - val_loss: 16.7750 - val_acc: 0.0000e+00
# Epoch 24/100
# 2/2 [==============================] - 40s 20s/step - loss: 17.0676 - acc: 0.0000e+00 - val_loss: 16.4307 - val_acc: 0.0312
# Epoch 25/100
# 2/2 [==============================] - 38s 19s/step - loss: 16.2086 - acc: 0.0156 - val_loss: 15.8078 - val_acc: 0.0312
# Epoch 26/100
# 2/2 [==============================] - 38s 19s/step - loss: 15.0064 - acc: 0.0156 - val_loss: 14.9401 - val_acc: 0.0156
# Epoch 27/100
# 2/2 [==============================] - 38s 19s/step - loss: 14.7124 - acc: 0.0312 - val_loss: 14.0745 - val_acc: 0.0312
# Epoch 28/100
# 2/2 [==============================] - 32s 16s/step - loss: 14.4406 - acc: 0.0156 - val_loss: 13.6318 - val_acc: 0.0156
# Epoch 29/100
# 2/2 [==============================] - 31s 15s/step - loss: 13.3581 - acc: 0.0156 - val_loss: 13.6876 - val_acc: 0.0156
# Epoch 30/100
# 2/2 [==============================] - 30s 15s/step - loss: 12.9878 - acc: 0.0312 - val_loss: 13.4548 - val_acc: 0.0000e+00
# Epoch 31/100
# 2/2 [==============================] - 30s 15s/step - loss: 12.4720 - acc: 0.0156 - val_loss: 12.4575 - val_acc: 0.0312
# Epoch 32/100
# 2/2 [==============================] - 31s 15s/step - loss: 11.9754 - acc: 0.0000e+00 - val_loss: 11.3891 - val_acc: 0.0312
# Epoch 33/100
# 2/2 [==============================] - 35s 18s/step - loss: 11.0290 - acc: 0.0469 - val_loss: 10.7632 - val_acc: 0.0312
# Epoch 34/100
# 2/2 [==============================] - 38s 19s/step - loss: 10.2232 - acc: 0.0156 - val_loss: 10.2050 - val_acc: 0.0156
# Epoch 35/100
# 2/2 [==============================] - 50s 25s/step - loss: 9.7355 - acc: 0.0312 - val_loss: 9.9749 - val_acc: 0.0469
# Epoch 36/100
# 2/2 [==============================] - 52s 26s/step - loss: 9.6005 - acc: 0.0000e+00 - val_loss: 10.5715 - val_acc: 0.0000e+00
# Epoch 37/100
# 2/2 [==============================] - 51s 26s/step - loss: 9.0688 - acc: 0.0156 - val_loss: 11.5956 - val_acc: 0.0000e+00
# Epoch 38/100
# 2/2 [==============================] - 50s 25s/step - loss: 8.4636 - acc: 0.0156 - val_loss: 10.6514 - val_acc: 0.0312
# Epoch 39/100
# 2/2 [==============================] - 51s 25s/step - loss: 8.4900 - acc: 0.0312 - val_loss: 7.8712 - val_acc: 0.0312
# Epoch 40/100
# 2/2 [==============================] - 51s 25s/step - loss: 7.1485 - acc: 0.0625 - val_loss: 6.6398 - val_acc: 0.0312
# Epoch 41/100
# 2/2 [==============================] - 52s 26s/step - loss: 6.6282 - acc: 0.0156 - val_loss: 8.9301 - val_acc: 0.0000e+00
# Epoch 42/100
# 2/2 [==============================] - 49s 25s/step - loss: 6.3322 - acc: 0.0156 - val_loss: 7.1673 - val_acc: 0.0000e+00
# Epoch 43/100
# 2/2 [==============================] - 49s 25s/step - loss: 6.1850 - acc: 0.0312 - val_loss: 5.5518 - val_acc: 0.0781
# Epoch 44/100
# 2/2 [==============================] - 50s 25s/step - loss: 5.7667 - acc: 0.0312 - val_loss: 4.9268 - val_acc: 0.1094
# Epoch 45/100
# 2/2 [==============================] - 52s 26s/step - loss: 5.5752 - acc: 0.0938 - val_loss: 5.3368 - val_acc: 0.1406
# Epoch 46/100
# 2/2 [==============================] - 47s 23s/step - loss: 5.1475 - acc: 0.0938 - val_loss: 7.6775 - val_acc: 0.0625
# Epoch 47/100
# 2/2 [==============================] - 49s 24s/step - loss: 4.7187 - acc: 0.0781 - val_loss: 7.8508 - val_acc: 0.0625
# Epoch 48/100
# 2/2 [==============================] - 31s 16s/step - loss: 4.6914 - acc: 0.0938 - val_loss: 6.1146 - val_acc: 0.0625
# Epoch 49/100
# 2/2 [==============================] - 41s 20s/step - loss: 4.6276 - acc: 0.0781 - val_loss: 4.2928 - val_acc: 0.1406
# Epoch 50/100
# 2/2 [==============================] - 50s 25s/step - loss: 4.7895 - acc: 0.0781 - val_loss: 4.1628 - val_acc: 0.0938
# Epoch 51/100
# 2/2 [==============================] - 51s 25s/step - loss: 4.3374 - acc: 0.1094 - val_loss: 7.8644 - val_acc: 0.0781
# Epoch 52/100
# 2/2 [==============================] - 53s 27s/step - loss: 4.5400 - acc: 0.0625 - val_loss: 12.9532 - val_acc: 0.0312
# Epoch 53/100
# 2/2 [==============================] - 29s 15s/step - loss: 4.0703 - acc: 0.0781 - val_loss: 12.3871 - val_acc: 0.0312
# Epoch 54/100
# 2/2 [==============================] - 30s 15s/step - loss: 4.4519 - acc: 0.0938 - val_loss: 8.4709 - val_acc: 0.0469
# Epoch 55/100
# 2/2 [==============================] - 29s 15s/step - loss: 4.3730 - acc: 0.1094 - val_loss: 4.2204 - val_acc: 0.0781
# Epoch 56/100
# 2/2 [==============================] - 30s 15s/step - loss: 4.5357 - acc: 0.1250 - val_loss: 4.3017 - val_acc: 0.0781
# Epoch 57/100
# 2/2 [==============================] - 29s 15s/step - loss: 4.7263 - acc: 0.0781 - val_loss: 9.1323 - val_acc: 0.0625
# Epoch 58/100
# 2/2 [==============================] - 29s 15s/step - loss: 4.1834 - acc: 0.0781 - val_loss: 20.4331 - val_acc: 0.0156
# Epoch 59/100
# 2/2 [==============================] - 29s 15s/step - loss: 4.1587 - acc: 0.1094 - val_loss: 23.5603 - val_acc: 0.0156
# Epoch 60/100
# 2/2 [==============================] - 30s 15s/step - loss: 4.2339 - acc: 0.0625 - val_loss: 9.8063 - val_acc: 0.0625
# 2/2 [==============================] - 12s 6s/step
# 17
# 20
# Epoch 1/100
# 8/8 [==============================] - 112s 14s/step - loss: 7.7493 - acc: 0.0352 - val_loss: 5.4696 - val_acc: 0.0703
# Epoch 2/100
# 8/8 [==============================] - 113s 14s/step - loss: 6.8488 - acc: 0.0273 - val_loss: 6.7422 - val_acc: 0.0508
# Epoch 3/100
# 8/8 [==============================] - 148s 19s/step - loss: 6.4609 - acc: 0.0703 - val_loss: 6.1545 - val_acc: 0.0664
# Epoch 4/100
# 8/8 [==============================] - 151s 19s/step - loss: 6.1121 - acc: 0.0586 - val_loss: 8.3316 - val_acc: 0.0391
# Epoch 5/100
# 8/8 [==============================] - 139s 17s/step - loss: 5.6535 - acc: 0.0625 - val_loss: 7.0253 - val_acc: 0.0469
# Epoch 6/100
# 8/8 [==============================] - 137s 17s/step - loss: 5.8492 - acc: 0.0664 - val_loss: 6.9640 - val_acc: 0.0352
# Epoch 7/100
# 8/8 [==============================] - 155s 19s/step - loss: 5.4185 - acc: 0.0625 - val_loss: 8.6352 - val_acc: 0.0234
# Epoch 8/100
# 8/8 [==============================] - 155s 19s/step - loss: 5.3292 - acc: 0.0508 - val_loss: 6.8117 - val_acc: 0.0391
# Epoch 9/100
# 8/8 [==============================] - 152s 19s/step - loss: 5.3698 - acc: 0.0469 - val_loss: 6.3532 - val_acc: 0.0547
# Epoch 10/100
# 8/8 [==============================] - 144s 18s/step - loss: 5.1120 - acc: 0.0664 - val_loss: 4.1787 - val_acc: 0.0898
# Epoch 11/100
# 8/8 [==============================] - 128s 16s/step - loss: 5.4145 - acc: 0.0703 - val_loss: 8.4547 - val_acc: 0.0156
# Epoch 12/100
# 8/8 [==============================] - 120s 15s/step - loss: 4.7476 - acc: 0.0820 - val_loss: 9.2906 - val_acc: 0.0117
# Epoch 13/100
# 8/8 [==============================] - 119s 15s/step - loss: 4.6906 - acc: 0.0625 - val_loss: 6.9434 - val_acc: 0.0156
# Epoch 14/100
# 8/8 [==============================] - 137s 17s/step - loss: 4.4934 - acc: 0.0625 - val_loss: 15.9460 - val_acc: 0.0039
# Epoch 15/100
# 8/8 [==============================] - 132s 17s/step - loss: 4.1886 - acc: 0.0742 - val_loss: 3.7408 - val_acc: 0.0859
# Epoch 16/100
# 8/8 [==============================] - 130s 16s/step - loss: 4.6242 - acc: 0.0742 - val_loss: 5.8739 - val_acc: 0.0234
# Epoch 17/100
# 8/8 [==============================] - 122s 15s/step - loss: 4.3318 - acc: 0.0898 - val_loss: 8.3029 - val_acc: 0.0195
# Epoch 18/100
# 8/8 [==============================] - 123s 15s/step - loss: 4.3550 - acc: 0.0391 - val_loss: 5.4601 - val_acc: 0.0664
# Epoch 19/100
# 8/8 [==============================] - 127s 16s/step - loss: 3.9560 - acc: 0.0664 - val_loss: 13.5037 - val_acc: 0.0078
# Epoch 20/100
# 8/8 [==============================] - 122s 15s/step - loss: 3.9924 - acc: 0.1250 - val_loss: 4.6268 - val_acc: 0.0898
# Epoch 21/100
# 8/8 [==============================] - 127s 16s/step - loss: 4.2108 - acc: 0.0703 - val_loss: 3.7611 - val_acc: 0.0664
# Epoch 22/100
# 8/8 [==============================] - 139s 17s/step - loss: 3.8361 - acc: 0.0664 - val_loss: 6.7180 - val_acc: 0.0234
# Epoch 23/100
# 8/8 [==============================] - 150s 19s/step - loss: 4.1331 - acc: 0.0820 - val_loss: 4.0225 - val_acc: 0.0781
# Epoch 24/100
# 8/8 [==============================] - 152s 19s/step - loss: 3.9114 - acc: 0.0820 - val_loss: 4.1531 - val_acc: 0.0938
# Epoch 25/100
# 8/8 [==============================] - 151s 19s/step - loss: 3.6768 - acc: 0.0938 - val_loss: 4.3781 - val_acc: 0.0664
# 8/8 [==============================] - 50s 6s/step
# 3
# 8/8 [==============================] - 46s 6s/step
# 2
# 8/8 [==============================] - 45s 6s/step
# 6
# 8/8 [==============================] - 44s 6s/step
