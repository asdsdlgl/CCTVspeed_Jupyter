# %%
from keras import *
from keras.layers import *


def c3d():
    # ToDo: params for CNN model

    input1 = Input(shape=(50, 72, 106, 1))
    cnn1 = Conv3D(32, (3, 3, 3), strides=(1, 2, 2), padding='same', data_format='channels_last')(input1)
    cnn1 = BatchNormalization()(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization()(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization()(cnn1)
    cnn1 = Activation('relu')(cnn1)
    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization()(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization()(cnn1)
    cnn1 = Activation('relu')(cnn1)
    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization()(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization()(cnn1)
    cnn1 = Activation('relu')(cnn1)
    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization()(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Flatten()(cnn1)
    dense = Dense(256, activation='relu')(cnn1)
    dense = Dense(256, activation='relu')(dense)
    out = Dense(1)(dense)
    model = Model(inputs=input1, outputs=out)
    model.compile(loss='mae',
                  optimizer='adam',
                  metrics=['accuracy'])
    model.summary()
    return "C3D", model


def c6g3():
    # ToDo: params for CNN model

    input1 = Input(shape=(50, 72, 106, 1))
    cnn1 = Conv3D(32, (3, 3, 3), strides=(1, 2, 2), padding='same', data_format='channels_last')(input1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = Activation('relu')(cnn1)
    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = Activation('relu')(cnn1)
    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = TimeDistributed(Flatten())(cnn1)

    gru = GRU(units=128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(cnn1)
    gru = GRU(units=128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(gru)
    gru = GRU(units=128, return_sequences=False, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(gru)
    # dense = Dense(int(node / 2), activation='relu')(dense)
    out = Dense(1)(gru)
    model = Model(inputs=input1, outputs=out)
    model.compile(loss='mae',
                  optimizer='adam',
                  metrics=['accuracy'])
    model.summary()
    return "C6G3", model


def c5g6():
    # ToDo: params for CNN model

    input1 = Input(shape=(50, 72, 106, 1))
    cnn1 = Conv3D(32, (3, 3, 3), strides=(1, 2, 2), padding='same', data_format='channels_last')(input1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = Activation('relu')(cnn1)
    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = TimeDistributed(Flatten())(cnn1)

    gru = GRU(units=128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(cnn1)
    gru = GRU(units=128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(gru)
    gru = GRU(units=128, return_sequences=False, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(gru)
    # dense = Dense(int(node / 2), activation='relu')(dense)
    out = Dense(1)(gru)
    model = Model(inputs=input1, outputs=out)
    model.compile(loss='mae',
                  optimizer='adam',
                  metrics=['accuracy'])
    model.summary()
    return "C5G6", model


def c4g12():
    # ToDo: params for CNN model

    input1 = Input(shape=(50, 72, 106, 1))
    cnn1 = Conv3D(32, (3, 3, 3), strides=(1, 2, 2), padding='same', data_format='channels_last')(input1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((1, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = Activation('relu')(cnn1)
    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = TimeDistributed(Flatten())(cnn1)

    gru = GRU(units=128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(cnn1)
    gru = GRU(units=128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(gru)
    gru = GRU(units=128, return_sequences=False, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(gru)
    # dense = Dense(int(node / 2), activation='relu')(dense)
    out = Dense(1)(gru)
    model = Model(inputs=input1, outputs=out)
    model.compile(loss='mae',
                  optimizer='adam',
                  metrics=['accuracy'])
    model.summary()
    return "C4G12", model


def c3g25():
    # ToDo: params for CNN model

    input1 = Input(shape=(50, 72, 106, 1))
    cnn1 = Conv3D(32, (3, 3, 3), strides=(1, 2, 2), padding='same', data_format='channels_last')(input1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((1, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = MaxPool3D((2, 2, 2))(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = Conv3D(32, (3, 3, 3), padding='same', data_format='channels_last')(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = Activation('relu')(cnn1)

    cnn1 = TimeDistributed(Flatten())(cnn1)

    gru = GRU(units=128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(cnn1)
    gru = GRU(units=128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(gru)
    gru = GRU(units=128, return_sequences=False, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(gru)
    # dense = Dense(int(node / 2), activation='relu')(dense)
    out = Dense(1)(gru)
    model = Model(inputs=input1, outputs=out)
    model.compile(loss='mae',
                  optimizer=optimizers.SGD(lr=0.01, momentum=0.9, clipnorm=1., clipvalue=0.5),
                  metrics=['accuracy'])
    model.summary()
    return "C3G25", model


def lrcn():
    # ToDo: params for CNN model

    input1 = Input(shape=(50, 72, 106, 1))
    cnn1 = TimeDistributed(Conv2D(32, (3, 3), strides=(2, 2), padding='same', activation='relu'))(input1)
    cnn1 = TimeDistributed(MaxPool2D((2, 2)))(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu'))(cnn1)
    cnn1 = TimeDistributed(MaxPool2D((2, 2)))(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu'))(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu'))(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = TimeDistributed(MaxPool2D((2, 2)))(cnn1)
    cnn1 = TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu'))(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu'))(cnn1)
    cnn1 = BatchNormalization(momentum=0.9)(cnn1)
    cnn1 = TimeDistributed(MaxPool2D((2, 2)))(cnn1)

    cnn1 = TimeDistributed(Flatten())(cnn1)

    gru = GRU(units=128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(cnn1)
    gru = GRU(units=128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(gru)
    gru = GRU(units=128, return_sequences=False, dropout=0.3, recurrent_dropout=0.3,
              kernel_initializer='orthogonal', bias_initializer='ones')(gru)
    out = Dense(1)(gru)
    model = Model(inputs=input1, outputs=out)
    model.compile(loss='mae',
                  optimizer='adam',
                  metrics=['accuracy'])
    model.summary()
    return "LRCN", model
# Out:
# Using TensorFlow backend.
